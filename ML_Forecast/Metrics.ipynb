# %%
import pandas as pd
# Out:
# StatementMeta(, 813b9f62-e6aa-4ed5-86e1-a5db558d12ea, 4, Finished, Available, Finished)

# %% [markdown]
# ## Load Datasets

# %%
# Load datasets
#Products
s0094_all_prd = pd.read_csv("abfss://Projeto_ii_ML_models@onelake.dfs.fabric.microsoft.com/Konya_sales.Lakehouse/Files/METRICS_noexogeneous_week_all_dates_products_CROSSVAL_S0094.csv")
s0094_2018_prd = pd.read_csv("abfss://Projeto_ii_ML_models@onelake.dfs.fabric.microsoft.com/Konya_sales.Lakehouse/Files/METRICS_noexogeneous_week_all_from2018_products_CROSSVAL_S0094.csv")
#s0094_2019_prd = pd.read_csv('abfss://Projeto_ii_ML_models@onelake.dfs.fabric.microsoft.com/Konya_sales.Lakehouse/Files/CSV/METRICS_noexogeneous_week_from2019_products_S0094.csv')
s0030_all_prd = pd.read_csv('abfss://Projeto_ii_ML_models@onelake.dfs.fabric.microsoft.com/Konya_sales.Lakehouse/Files/METRICS_noexogeneous_week_all_dates_products_CROSSVAL_S0030.csv')
s0030_2018_prd= pd.read_csv('abfss://Projeto_ii_ML_models@onelake.dfs.fabric.microsoft.com/Konya_sales.Lakehouse/Files/METRICS_noexogeneous_week_all_from2018_products_CROSSVAL_S0030.csv')
#s0030_2019_prd = pd.read_csv('abfss://Projeto_ii_ML_models@onelake.dfs.fabric.microsoft.com/Konya_sales.Lakehouse/Files/CSV/METRICS_noexogeneous_week_from2019_products_S0030.csv')
s0142_all_prd = pd.read_csv("abfss://Projeto_ii_ML_models@onelake.dfs.fabric.microsoft.com/Konya_sales.Lakehouse/Files/METRICS_noexogeneous_week_all_dates_products_CROSSVAL_S0142.csv")
s0142_2018_prd= pd.read_csv("abfss://Projeto_ii_ML_models@onelake.dfs.fabric.microsoft.com/Konya_sales.Lakehouse/Files/METRICS_noexogeneous_week_all_from2018_products_CROSSVAL_S0142.csv")
#s0142_2019_prd= pd.read_csv('abfss://Projeto_ii_ML_models@onelake.dfs.fabric.microsoft.com/Konya_sales.Lakehouse/Files/CSV/METRICS_noexogeneous_week_from2019_products_S0142.csv')

#Clusters
s0094_all_clus = pd.read_csv('abfss://Projeto_ii_ML_models@onelake.dfs.fabric.microsoft.com/Konya_sales.Lakehouse/Files/METRICS_noexogeneous_week_all_dates_clusters_CROSSVAL_S0094.csv')
s0094_2018_clus = pd.read_csv("abfss://Projeto_ii_ML_models@onelake.dfs.fabric.microsoft.com/Konya_sales.Lakehouse/Files/METRICS_noexogeneous_week_all_from2018_clusters_CROSSVAL_S0094.csv")
#s0094_2019_clus = pd.read_csv('abfss://Projeto_ii_ML_models@onelake.dfs.fabric.microsoft.com/Konya_sales.Lakehouse/Files/CSV/METRICS_noexogeneous_week_from2019_clusters_S0094.csv')
s0030_all_clus = pd.read_csv('abfss://Projeto_ii_ML_models@onelake.dfs.fabric.microsoft.com/Konya_sales.Lakehouse/Files/METRICS_noexogeneous_week_all_dates_clusters_CROSSVAL_S0030.csv')
s0030_2018_clus = pd.read_csv('abfss://Projeto_ii_ML_models@onelake.dfs.fabric.microsoft.com/Konya_sales.Lakehouse/Files/METRICS_noexogeneous_week_all_from2018_clusters_CROSSVAL_S0030.csv')
#s0030_2019_clus = pd.read_csv('abfss://Projeto_ii_ML_models@onelake.dfs.fabric.microsoft.com/Konya_sales.Lakehouse/Files/CSV/METRICS_noexogeneous_week_from2019_clusters_S0030.csv')
s0142_all_clus = pd.read_csv("abfss://Projeto_ii_ML_models@onelake.dfs.fabric.microsoft.com/Konya_sales.Lakehouse/Files/METRICS_noexogeneous_week_all_dates_clusters_CROSSVAL_S0142.csv")
s0142_2018_clus = pd.read_csv("abfss://Projeto_ii_ML_models@onelake.dfs.fabric.microsoft.com/Konya_sales.Lakehouse/Files/METRICS_noexogeneous_week_all_from2018_clusters_CROSSVAL_S0142.csv")
#s0142_2019_clus = pd.read_csv('abfss://Projeto_ii_ML_models@onelake.dfs.fabric.microsoft.com/Konya_sales.Lakehouse/Files/CSV/METRICS_noexogeneous_week_from2019_clusters_S0142.csv')


#top 3 products
top_s0030_all=pd.read_csv('abfss://Projeto_ii_ML_models@onelake.dfs.fabric.microsoft.com/Konya_sales.Lakehouse/Files/METRICS_noexogeneous_week_all_dates_products_CROSSVAL_S0030_TOP_3.csv')
top_s0030_2018=pd.read_csv('abfss://Projeto_ii_ML_models@onelake.dfs.fabric.microsoft.com/Konya_sales.Lakehouse/Files/METRICS_noexogeneous_week_from2018_products_CROSSVAL_S0030_TOP_3.csv')
top_s0094_all=pd.read_csv('abfss://Projeto_ii_ML_models@onelake.dfs.fabric.microsoft.com/Konya_sales.Lakehouse/Files/METRICS_noexogeneous_week_all_dates_products_CROSSVAL_S0094_TOP_3.csv')
top_s0094_2018=pd.read_csv('abfss://Projeto_ii_ML_models@onelake.dfs.fabric.microsoft.com/Konya_sales.Lakehouse/Files/METRICS_noexogeneous_week_from2018_products_CROSSVAL_S0094_TOP_3.csv')
top_s0142_all=pd.read_csv('abfss://Projeto_ii_ML_models@onelake.dfs.fabric.microsoft.com/Konya_sales.Lakehouse/Files/METRICS_noexogeneous_week_all_dates_products_CROSSVAL_S0142_TOP_3.csv')
top_s0142_2018=pd.read_csv('abfss://Projeto_ii_ML_models@onelake.dfs.fabric.microsoft.com/Konya_sales.Lakehouse/Files/METRICS_noexogeneous_week_from2018_products_CROSSVAL_S0142_TOP_3.csv')
# Out:
# StatementMeta(, 813b9f62-e6aa-4ed5-86e1-a5db558d12ea, 11, Finished, Available, Finished)

# %% [markdown]
# ## S0094

# %% [markdown]
# ### **Products**

# %%
mean_prd_s0094_all= s0094_all_prd.copy()

mean_prd_s0094_all['Store_ID'] = 'S0094'

mean_prd_s0094_all.drop('unique_id', axis=1, inplace=True)

mean_prd_s0094_all = mean_prd_s0094_all.groupby('Store_ID').mean().reset_index()

mean_prd_s0094_all['Method']='Product'

mean_prd_s0094_all['Time']='All'

mean_prd_s0094_all = mean_prd_s0094_all[['Method','Time','Store_ID', 'MAE', 'WMAPE', 'RMSE']]

mean_prd_s0094_all
# Out:
# StatementMeta(, c5d5bccd-45b9-4378-8c40-8a5a4f2169f9, 5, Finished, Available, Finished)
#     Method Time Store_ID       MAE     WMAPE      RMSE
# 0  Product  All    S0094  1.840778  0.001462  2.441318

# %%
mean_prd_s0094_2018= s0094_2018_prd.copy()

mean_prd_s0094_2018['Store_ID'] = 'S0094'

mean_prd_s0094_2018.drop('unique_id', axis=1, inplace=True)

mean_prd_s0094_2018 = mean_prd_s0094_2018.groupby('Store_ID').mean().reset_index()

mean_prd_s0094_2018['Method']='Product'

mean_prd_s0094_2018['Time']='2018'

mean_prd_s0094_2018 = mean_prd_s0094_2018[['Method','Time','Store_ID', 'MAE', 'WMAPE', 'RMSE']]

mean_prd_s0094_2018
# Out:
# StatementMeta(, c5d5bccd-45b9-4378-8c40-8a5a4f2169f9, 6, Finished, Available, Finished)
#     Method  Time Store_ID      MAE     WMAPE      RMSE
# 0  Product  2018    S0094  1.84826  0.001487  2.462378

# %% [markdown]
# ### **Clusters**

# %%
mean_cls_s0094_all= s0094_all_clus.copy()

mean_cls_s0094_all['Store_ID'] = 'S0094'

mean_cls_s0094_all.drop('unique_id', axis=1, inplace=True)

mean_cls_s0094_all = mean_cls_s0094_all.groupby('Store_ID').mean().reset_index()

mean_cls_s0094_all['Method']='Cluster'

mean_cls_s0094_all['Time']='All'

mean_cls_s0094_all = mean_cls_s0094_all[['Method','Time','Store_ID', 'MAE', 'WMAPE', 'RMSE']]

mean_cls_s0094_all
# Out:
# StatementMeta(, c5d5bccd-45b9-4378-8c40-8a5a4f2169f9, 7, Finished, Available, Finished)
#     Method Time Store_ID        MAE     WMAPE       RMSE
# 0  Cluster  All    S0094  34.621229  0.036553  40.307692

# %%
mean_cls_s0094_2018= s0094_2018_clus.copy()

mean_cls_s0094_2018['Store_ID'] = 'S0094'

mean_cls_s0094_2018.drop('unique_id', axis=1, inplace=True)

mean_cls_s0094_2018 = mean_cls_s0094_2018.groupby('Store_ID').mean().reset_index()

mean_cls_s0094_2018['Method']='Cluster'

mean_cls_s0094_2018['Time']='2018'

mean_cls_s0094_2018 = mean_cls_s0094_2018[['Method','Time','Store_ID', 'MAE', 'WMAPE', 'RMSE']]

mean_cls_s0094_2018
# Out:
# StatementMeta(, c5d5bccd-45b9-4378-8c40-8a5a4f2169f9, 8, Finished, Available, Finished)
#     Method  Time Store_ID        MAE     WMAPE       RMSE
# 0  Cluster  2018    S0094  33.989883  0.035886  39.213085

# %% [markdown]
# ### **Top 3**

# %%
top_s0094_all['Store_ID'] = 'S0094'

top_s0094_all['Method']='W/o Exog'

top_s0094_all['Time']='all'

top_s0094_all = top_s0094_all[['Method','Time','Store_ID','unique_id', 'MAE', 'WMAPE', 'RMSE']]

top_s0094_all
# Out:
# StatementMeta(, 813b9f62-e6aa-4ed5-86e1-a5db558d12ea, 12, Finished, Available, Finished)
#      Method Time Store_ID unique_id        MAE     WMAPE       RMSE
# 0  W/o Exog  all    S0094     P0125  27.643476  0.028280  36.374990
# 1  W/o Exog  all    S0094     P0453   2.562689  0.002342   3.493325
# 2  W/o Exog  all    S0094     P0536   2.382122  0.002437   2.587214

# %%
top_s0094_2018['Store_ID'] = 'S0094'

top_s0094_2018['Method']='W/o Exog'

top_s0094_2018['Time']='2018'

top_s0094_2018 = top_s0094_2018[['Method','Time','Store_ID','unique_id', 'MAE', 'WMAPE', 'RMSE']]

top_s0094_2018
# Out:
# StatementMeta(, 813b9f62-e6aa-4ed5-86e1-a5db558d12ea, 13, Finished, Available, Finished)
#     Method  Time Store_ID unique_id        MAE     WMAPE       RMSE
# 0  W/ Exog  2018    S0094     P0125  34.332230  0.035123  40.658794
# 1  W/ Exog  2018    S0094     P0453   2.371820  0.002146   3.275844
# 2  W/ Exog  2018    S0094     P0536   2.258646  0.002311   2.470632

# %% [markdown]
# ## S0030

# %% [markdown]
# ### **Products**

# %%
mean_prd_s0030_all= s0030_all_prd.copy()

mean_prd_s0030_all['Store_ID'] = 'S0030'

mean_prd_s0030_all.drop('unique_id', axis=1, inplace=True)

mean_prd_s0030_all = mean_prd_s0030_all.groupby('Store_ID').mean().reset_index()

mean_prd_s0030_all['Method']='Product'

mean_prd_s0030_all['Time']='All'

mean_prd_s0030_all = mean_prd_s0030_all[['Method','Time','Store_ID', 'MAE', 'WMAPE', 'RMSE']]

mean_prd_s0030_all
# Out:
# StatementMeta(, c5d5bccd-45b9-4378-8c40-8a5a4f2169f9, 9, Finished, Available, Finished)
#     Method Time Store_ID       MAE     WMAPE      RMSE
# 0  Product  All    S0030  0.970903  0.005868  1.362339

# %%
mean_prd_s0030_2018= s0030_2018_prd.copy()

mean_prd_s0030_2018['Store_ID'] = 'S0030'

mean_prd_s0030_2018.drop('unique_id', axis=1, inplace=True)

mean_prd_s0030_2018 = mean_prd_s0030_2018.groupby('Store_ID').mean().reset_index()

mean_prd_s0030_2018['Method']='Product'

mean_prd_s0030_2018['Time']='2018'

mean_prd_s0030_2018 = mean_prd_s0030_2018[['Method','Time','Store_ID', 'MAE', 'WMAPE', 'RMSE']]

mean_prd_s0030_2018
# Out:
# StatementMeta(, c5d5bccd-45b9-4378-8c40-8a5a4f2169f9, 10, Finished, Available, Finished)
#     Method  Time Store_ID       MAE     WMAPE      RMSE
# 0  Product  2018    S0030  0.998635  0.006178  1.404246

# %% [markdown]
# ### **Clusters**

# %%
mean_cls_s0030_all= s0030_all_clus.copy()

mean_cls_s0030_all['Store_ID'] = 'S0030'

mean_cls_s0030_all.drop('unique_id', axis=1, inplace=True)

mean_cls_s0030_all = mean_cls_s0030_all.groupby('Store_ID').mean().reset_index()

mean_cls_s0030_all['Method']='Cluster'

mean_cls_s0030_all['Time']='All'

mean_cls_s0030_all = mean_cls_s0030_all[['Method','Time','Store_ID', 'MAE', 'WMAPE', 'RMSE']]

mean_cls_s0030_all
# Out:
# StatementMeta(, c5d5bccd-45b9-4378-8c40-8a5a4f2169f9, 11, Finished, Available, Finished)
#     Method Time Store_ID       MAE     WMAPE      RMSE
# 0  Cluster  All    S0030  3.701187  0.030154  4.767312

# %%
mean_cls_s0030_2018= s0030_2018_clus.copy()

mean_cls_s0030_2018['Store_ID'] = 'S0030'

mean_cls_s0030_2018.drop('unique_id', axis=1, inplace=True)

mean_cls_s0030_2018 = mean_cls_s0030_2018.groupby('Store_ID').mean().reset_index()

mean_cls_s0030_2018['Method']='Cluster'

mean_cls_s0030_2018['Time']='2018'

mean_cls_s0030_2018 = mean_cls_s0030_2018[['Method','Time','Store_ID', 'MAE', 'WMAPE', 'RMSE']]

mean_cls_s0030_2018
# Out:
# StatementMeta(, c5d5bccd-45b9-4378-8c40-8a5a4f2169f9, 12, Finished, Available, Finished)
#     Method  Time Store_ID       MAE     WMAPE      RMSE
# 0  Cluster  2018    S0030  3.581475  0.029615  4.704418

# %% [markdown]
# ### **Top 3**

# %%
top_s0030_all['Store_ID'] = 'S0030'

top_s0030_all['Method']='W/o Exog'

top_s0030_all['Time']='all'

top_s0030_all = top_s0030_all[['Method','Time','Store_ID','unique_id', 'MAE', 'WMAPE', 'RMSE']]

top_s0030_all
# Out:
# StatementMeta(, 813b9f62-e6aa-4ed5-86e1-a5db558d12ea, 15, Finished, Available, Finished)
#      Method Time Store_ID unique_id        MAE     WMAPE       RMSE
# 0  W/o Exog  all    S0030     P0125  27.643476  0.028280  36.374990
# 1  W/o Exog  all    S0030     P0453   2.562689  0.002342   3.493325
# 2  W/o Exog  all    S0030     P0536   2.382122  0.002437   2.587214

# %%
top_s0030_2018['Store_ID'] = 'S0030'

top_s0030_2018['Method']='W/o Exog'

top_s0030_2018['Time']='2018'

top_s0030_2018 = top_s0030_2018[['Method','Time','Store_ID','unique_id', 'MAE', 'WMAPE', 'RMSE']]

top_s0030_2018
# Out:
# StatementMeta(, 813b9f62-e6aa-4ed5-86e1-a5db558d12ea, 16, Finished, Available, Finished)
#     Method  Time Store_ID unique_id       MAE     WMAPE      RMSE
# 0  W/ Exog  2018    S0030     P0125  1.216807  0.007457  1.544019
# 1  W/ Exog  2018    S0030     P0453  2.500000  0.018634  6.123724
# 2  W/ Exog  2018    S0030     P0536  0.752835  0.002143  0.908325

# %% [markdown]
# ## S0142

# %% [markdown]
# ### **Products**

# %%
mean_prd_s0142_all= s0142_all_prd.copy()

mean_prd_s0142_all['Store_ID'] = 'S0142'

mean_prd_s0142_all.drop('unique_id', axis=1, inplace=True)

mean_prd_s0142_all = mean_prd_s0142_all.groupby('Store_ID').mean().reset_index()

mean_prd_s0142_all['Method']='Product'

mean_prd_s0142_all['Time']='All'

mean_prd_s0142_all = mean_prd_s0142_all[['Method','Time','Store_ID', 'MAE', 'WMAPE', 'RMSE']]

mean_prd_s0142_all
# Out:
# StatementMeta(, c5d5bccd-45b9-4378-8c40-8a5a4f2169f9, 13, Finished, Available, Finished)
#     Method Time Store_ID       MAE     WMAPE      RMSE
# 0  Product  All    S0142  0.904079  0.002069  1.179101

# %%
mean_prd_s0142_2018= s0142_2018_prd.copy()

mean_prd_s0142_2018['Store_ID'] = 'S0142'

mean_prd_s0142_2018.drop('unique_id', axis=1, inplace=True)

mean_prd_s0142_2018 = mean_prd_s0142_2018.groupby('Store_ID').mean().reset_index()

mean_prd_s0142_2018['Method']='Product'

mean_prd_s0142_2018['Time']='2018'

mean_prd_s0142_2018 = mean_prd_s0142_2018[['Method','Time','Store_ID', 'MAE', 'WMAPE', 'RMSE']]

mean_prd_s0142_2018
# Out:
# StatementMeta(, c5d5bccd-45b9-4378-8c40-8a5a4f2169f9, 14, Finished, Available, Finished)
#     Method  Time Store_ID       MAE     WMAPE      RMSE
# 0  Product  2018    S0142  0.883342  0.002105  1.161447

# %% [markdown]
# ### **Clusters**

# %%
mean_cls_s0142_all= s0142_all_clus.copy()

mean_cls_s0142_all['Store_ID'] = 'S0142'

mean_cls_s0142_all.drop('unique_id', axis=1, inplace=True)

mean_cls_s0142_all = mean_cls_s0142_all.groupby('Store_ID').mean().reset_index()

mean_cls_s0142_all['Method']='Cluster'

mean_cls_s0142_all['Time']='All'

mean_cls_s0142_all = mean_cls_s0142_all[['Method','Time','Store_ID', 'MAE', 'WMAPE', 'RMSE']]

mean_cls_s0142_all
# Out:
# StatementMeta(, c5d5bccd-45b9-4378-8c40-8a5a4f2169f9, 15, Finished, Available, Finished)
#     Method Time Store_ID        MAE     WMAPE       RMSE
# 0  Cluster  All    S0142  12.262396  0.043228  17.477429

# %%
mean_cls_s0142_2018= s0142_2018_clus.copy()

mean_cls_s0142_2018['Store_ID'] = 'S0142'

mean_cls_s0142_2018.drop('unique_id', axis=1, inplace=True)

mean_cls_s0142_2018 = mean_cls_s0142_2018.groupby('Store_ID').mean().reset_index()

mean_cls_s0142_2018['Method']='Cluster'

mean_cls_s0142_2018['Time']='2018'

mean_cls_s0142_2018 = mean_cls_s0142_2018[['Method','Time','Store_ID', 'MAE', 'WMAPE', 'RMSE']]

mean_cls_s0142_2018
# Out:
# StatementMeta(, c5d5bccd-45b9-4378-8c40-8a5a4f2169f9, 16, Finished, Available, Finished)
#     Method  Time Store_ID        MAE    WMAPE       RMSE
# 0  Cluster  2018    S0142  11.783523  0.04154  16.795772

# %% [markdown]
# ### **Top 3**

# %%
top_s0142_all['Store_ID'] = 'S0142'

top_s0142_all['Method']='W/o Exog'

top_s0142_all['Time']='all'

top_s0142_all = top_s0142_all[['Method','Time','Store_ID','unique_id', 'MAE', 'WMAPE', 'RMSE']]

top_s0142_all
# Out:
# StatementMeta(, 813b9f62-e6aa-4ed5-86e1-a5db558d12ea, 17, Finished, Available, Finished)
#      Method Time Store_ID unique_id       MAE     WMAPE      RMSE
# 0  W/o Exog  all    S0142     P0125  1.407929  0.002727  1.690351
# 1  W/o Exog  all    S0142     P0453  0.000001  0.000000  0.000002
# 2  W/o Exog  all    S0142     P0536  1.750968  0.005627  1.913117

# %%
top_s0142_2018['Store_ID'] = 'S0142'

top_s0142_2018['Method']='W/o Exog'

top_s0142_2018['Time']='2018'

top_s0142_2018 = top_s0142_2018[['Method','Time','Store_ID','unique_id', 'MAE', 'WMAPE', 'RMSE']]

top_s0142_2018
# Out:
# StatementMeta(, 813b9f62-e6aa-4ed5-86e1-a5db558d12ea, 18, Finished, Available, Finished)
#     Method  Time Store_ID unique_id       MAE     WMAPE      RMSE
# 0  W/ Exog  2018    S0142     P0125  1.470299  0.003089  1.776502
# 1  W/ Exog  2018    S0142     P0453  0.001281  0.000000  0.001363
# 2  W/ Exog  2018    S0142     P0536  1.460014  0.004869  1.825122

# %% [markdown]
# ## Concatenate and save

# %% [markdown]
# ### Products vs clusters

# %%
#Concatenate the DataFrames by rows - S0094
metrics_s0094 = pd.concat([mean_prd_s0094_all, mean_prd_s0094_2018, mean_cls_s0094_all, mean_cls_s0094_2018], ignore_index=True)
metrics_s0094
# Out:
# StatementMeta(, c5d5bccd-45b9-4378-8c40-8a5a4f2169f9, 17, Finished, Available, Finished)
#     Method  Time Store_ID        MAE     WMAPE       RMSE
# 0  Product   All    S0094   1.840778  0.001462   2.441318
# 1  Product  2018    S0094   1.848260  0.001487   2.462378
# 2  Cluster   All    S0094  34.621229  0.036553  40.307692
# 3  Cluster  2018    S0094  33.989883  0.035886  39.213085

# %%
#Concatenate the DataFrames by rows - S0030
metrics_s0030 = pd.concat([mean_prd_s0030_all, mean_prd_s0030_2018, mean_cls_s0030_all, mean_cls_s0030_2018], ignore_index=True)
metrics_s0030
# Out:
# StatementMeta(, c5d5bccd-45b9-4378-8c40-8a5a4f2169f9, 18, Finished, Available, Finished)
#     Method  Time Store_ID       MAE     WMAPE      RMSE
# 0  Product   All    S0030  0.970903  0.005868  1.362339
# 1  Product  2018    S0030  0.998635  0.006178  1.404246
# 2  Cluster   All    S0030  3.701187  0.030154  4.767312
# 3  Cluster  2018    S0030  3.581475  0.029615  4.704418

# %%
#Concatenate the DataFrames by rows - S0142
metrics_s0142 = pd.concat([mean_prd_s0142_all, mean_prd_s0142_2018, mean_cls_s0142_all, mean_cls_s0142_2018], ignore_index=True)
metrics_s0142
# Out:
# StatementMeta(, c5d5bccd-45b9-4378-8c40-8a5a4f2169f9, 19, Finished, Available, Finished)
#     Method  Time Store_ID        MAE     WMAPE       RMSE
# 0  Product   All    S0142   0.904079  0.002069   1.179101
# 1  Product  2018    S0142   0.883342  0.002105   1.161447
# 2  Cluster   All    S0142  12.262396  0.043228  17.477429
# 3  Cluster  2018    S0142  11.783523  0.041540  16.795772

# %%
#Save all df as csv
metrics_s0030.to_csv('abfss://Projeto_ii_ML_models@onelake.dfs.fabric.microsoft.com/Konya_sales.Lakehouse/Files/Metrics_S0030.csv') 
metrics_s0094.to_csv('abfss://Projeto_ii_ML_models@onelake.dfs.fabric.microsoft.com/Konya_sales.Lakehouse/Files/Metrics_S0094.csv') 
metrics_s0142.to_csv('abfss://Projeto_ii_ML_models@onelake.dfs.fabric.microsoft.com/Konya_sales.Lakehouse/Files/Metrics_S0142.csv')
# Out:
# StatementMeta(, c5d5bccd-45b9-4378-8c40-8a5a4f2169f9, 20, Finished, Available, Finished)
