# %%
# !pip install statsforecast

import numpy as np
import pandas as pd
import pyarrow as pa
import pyarrow.parquet as pq
import pandas as pd
import matplotlib.pyplot as plt
from statsforecast import StatsForecast
from statsforecast.models import AutoARIMA
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder, StandardScaler, PowerTransformer
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.metrics import mean_squared_error
from statsmodels.tsa.stattools import adfuller
from sklearn.preprocessing import OneHotEncoder
from pylab import rcParams
import os
  
# Ignore harmless warnings 
import warnings 
warnings.filterwarnings("ignore")
# Out:
# StatementMeta(, 4c1f17b5-11af-4e1a-abc2-3092afa477d4, 3, Finished, Available, Finished)
# Collecting statsforecast
#   Downloading statsforecast-1.7.6-py3-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.6/134.6 kB 10.8 MB/s eta 0:00:00
# Requirement already satisfied: cloudpickle in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from statsforecast) (2.2.1)
# Collecting coreforecast>=0.0.12 (from statsforecast)
#   Downloading coreforecast-0.0.12-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (196 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.7/196.7 kB 16.1 MB/s eta 0:00:00
# Requirement already satisfied: numba>=0.55.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from statsforecast) (0.57.1)
# Requirement already satisfied: numpy>=1.21.6 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from statsforecast) (1.24.3)
# Requirement already satisfied: pandas>=1.3.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from statsforecast) (2.0.3)
# Requirement already satisfied: scipy>=1.7.3 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from statsforecast) (1.10.1)
# Requirement already satisfied: statsmodels>=0.13.2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from statsforecast) (0.14.0)
# Requirement already satisfied: tqdm in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from statsforecast) (4.66.1)
# Collecting fugue>=0.8.1 (from statsforecast)
#   Downloading fugue-0.9.1-py3-none-any.whl (278 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 86.1 MB/s eta 0:00:00
# Collecting utilsforecast>=0.1.4 (from statsforecast)
#   Downloading utilsforecast-0.2.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: threadpoolctl in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from statsforecast) (3.2.0)
# Collecting triad>=0.9.7 (from fugue>=0.8.1->statsforecast)
#   Downloading triad-0.9.8-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 kB 22.5 MB/s eta 0:00:00
# Collecting adagio>=0.2.4 (from fugue>=0.8.1->statsforecast)
#   Downloading adagio-0.2.4-py3-none-any.whl (26 kB)
# Requirement already satisfied: llvmlite<0.41,>=0.40.0dev0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from numba>=0.55.0->statsforecast) (0.40.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from pandas>=1.3.5->statsforecast) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from pandas>=1.3.5->statsforecast) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from pandas>=1.3.5->statsforecast) (2023.3)
# Requirement already satisfied: patsy>=0.5.2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from statsmodels>=0.13.2->statsforecast) (0.5.3)
# Requirement already satisfied: packaging>=21.3 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from statsmodels>=0.13.2->statsforecast) (23.2)
# Requirement already satisfied: six in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from patsy>=0.5.2->statsmodels>=0.13.2->statsforecast) (1.16.0)
# Requirement already satisfied: pyarrow>=6.0.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from triad>=0.9.7->fugue>=0.8.1->statsforecast) (12.0.1)
# Requirement already satisfied: fsspec>=2022.5.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from triad>=0.9.7->fugue>=0.8.1->statsforecast) (2023.10.0)
# Collecting fs (from triad>=0.9.7->fugue>=0.8.1->statsforecast)
#   Downloading fs-2.4.16-py2.py3-none-any.whl (135 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.3/135.3 kB 66.9 MB/s eta 0:00:00
# Requirement already satisfied: appdirs~=1.4.3 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from fs->triad>=0.9.7->fugue>=0.8.1->statsforecast) (1.4.4)
# Requirement already satisfied: setuptools in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from fs->triad>=0.9.7->fugue>=0.8.1->statsforecast) (68.2.2)
# Installing collected packages: fs, coreforecast, utilsforecast, triad, adagio, fugue, statsforecast
# Successfully installed adagio-0.2.4 coreforecast-0.0.12 fs-2.4.16 fugue-0.9.1 statsforecast-1.7.6 triad-0.9.8 utilsforecast-0.2.0

# %%
# Load dataset
konya = pd.read_parquet("abfss://Projeto_ii_ML_models@onelake.dfs.fabric.microsoft.com/Konya_sales.Lakehouse/Files/konya_features.parquet")
# Out:
# StatementMeta(, 4c1f17b5-11af-4e1a-abc2-3092afa477d4, 4, Finished, Available, Finished)

# %%
# vizualize dataset
konya.head()
konya.tail()

# print info
print(konya.info())
# Out:
# StatementMeta(, 4c1f17b5-11af-4e1a-abc2-3092afa477d4, 5, Finished, Available, Finished)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 532614 entries, 0 to 532613
# Data columns (total 32 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   store_id               532614 non-null  object
#  1   product_id             532614 non-null  object
#  2   date                   532614 non-null  datetime64[ns]
#  3   sales                  532614 non-null  float64
#  4   revenue                532614 non-null  float64
#  5   stock                  532614 non-null  float64
#  6   price                  531602 non-null  float64
#  7   promo_type_1           532614 non-null  category
#  8   promo_bin_1            75780 non-null   category
#  9   promo_type_2           532614 non-null  category
#  10  promo_bin_2            479 non-null     category
#  11  promo_discount_2       479 non-null     float64
#  12  promo_discount_type_2  479 non-null     category
#  13  product_length         529456 non-null  float64
#  14  product_depth          529481 non-null  float64
#  15  product_width          529481 non-null  float64
#  16  cluster_id             532614 non-null  category
#  17  hierarchy1_id          532614 non-null  category
#  18  hierarchy2_id          532614 non-null  category
#  19  hierarchy3_id          532614 non-null  category
#  20  hierarchy4_id          532614 non-null  category
#  21  hierarchy5_id          532614 non-null  category
#  22  storetype_id           532614 non-null  category
#  23  store_size             532614 non-null  int64
#  24  city_id_old            532614 non-null  object
#  25  country_id             532614 non-null  object
#  26  city_code              532614 non-null  object
#  27  weekday                532614 non-null  category
#  28  season                 532614 non-null  int64
#  29  week                   532614 non-null  int64
#  30  holiday                532614 non-null  category
#  31  month_name             532614 non-null  category
# dtypes: category(15), datetime64[ns](1), float64(8), int64(3), object(5)
# memory usage: 77.7+ MB
# None

# %%
# change dtypes 

cat_col = ['store_id', 'product_id', 'season', 'week']
konya[cat_col] = konya[cat_col].astype('category')

# Drop columns not necessary
df = konya.copy()
# List of columns to drop
columns_to_drop = [
    'promo_bin_1', 
    'promo_bin_2',
    'revenue', 
    'promo_discount_2', 
    'promo_discount_type_2', 
    'hierarchy2_id', 
    'hierarchy3_id', 
    'hierarchy4_id', 
    'hierarchy5_id', 
    'city_id_old', 
    'country_id', 
    'city_code',
    'product_length', 
    'product_depth',
    'product_width',
    'weekday'
]

# Drop the specified columns
df = df.drop(columns=columns_to_drop, errors='ignore')

#confirm drop
df.info()
# Out:
# StatementMeta(, 4c1f17b5-11af-4e1a-abc2-3092afa477d4, 6, Finished, Available, Finished)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 532614 entries, 0 to 532613
# Data columns (total 16 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   store_id       532614 non-null  category
#  1   product_id     532614 non-null  category
#  2   date           532614 non-null  datetime64[ns]
#  3   sales          532614 non-null  float64
#  4   stock          532614 non-null  float64
#  5   price          531602 non-null  float64
#  6   promo_type_1   532614 non-null  category
#  7   promo_type_2   532614 non-null  category
#  8   cluster_id     532614 non-null  category
#  9   hierarchy1_id  532614 non-null  category
#  10  storetype_id   532614 non-null  category
#  11  store_size     532614 non-null  int64
#  12  season         532614 non-null  category
#  13  week           532614 non-null  category
#  14  holiday        532614 non-null  category
#  15  month_name     532614 non-null  category
# dtypes: category(11), datetime64[ns](1), float64(3), int64(1)
# memory usage: 26.4 MB

# %%
# separate products that are not sold in 2019

# Ensure 'date' column is of datetime type
df['date'] = pd.to_datetime(df['date'])

# Filter products that are present in 2019
products_in_2019 = df[df['date'].dt.year == 2019]['product_id'].unique()

# Filter X_ts based on products in 2019
df_filtered = df[df['product_id'].isin(products_in_2019)]

# Example: Display the filtered DataFrame
print(df_filtered.head(20))
print(df['product_id'].nunique())
print(df_filtered['product_id'].nunique())
# Out:
# StatementMeta(, 4c1f17b5-11af-4e1a-abc2-3092afa477d4, 7, Finished, Available, Finished)
#    store_id product_id       date  sales  stock  price promo_type_1  \
# 0     S0030      P0015 2017-01-02    0.0    4.0   2.60         PR14
# 1     S0030      P0018 2017-01-02    1.0    5.0   1.95         PR14
# 2     S0030      P0035 2017-01-02    2.0    1.0   2.45         PR14
# 3     S0030      P0051 2017-01-02    0.0   27.0   0.70         PR14
# 4     S0030      P0055 2017-01-02    0.0   12.0   3.50         PR05
# 5     S0030      P0057 2017-01-02    0.0    4.0  12.90         PR14
# 6     S0030      P0062 2017-01-02    0.0    5.0  19.90         PR14
# 8     S0030      P0103 2017-01-02    0.0   13.0   2.65         PR14
# 9     S0030      P0114 2017-01-02    1.0   20.0   0.45         PR14
# 10    S0030      P0116 2017-01-02    3.0   16.0   0.85         PR14
# 11    S0030      P0125 2017-01-02    0.0    9.0   2.45         PR14
# 12    S0030      P0131 2017-01-02    0.0    9.0   2.25         PR14
# 13    S0030      P0171 2017-01-02    0.0    9.0   9.85         PR14
# 14    S0030      P0172 2017-01-02    0.0    1.0   3.50         PR14
# 15    S0030      P0185 2017-01-02    0.0    2.0   0.75         PR14
# 16    S0030      P0195 2017-01-02    0.0    1.0   5.75         PR14
# 17    S0030      P0201 2017-01-02    0.0    5.0  14.90         PR14
# 18    S0030      P0206 2017-01-02    0.0   16.0   1.75         PR14
# 19    S0030      P0260 2017-01-02    0.0   21.0  17.50         PR14
# 20    S0030      P0261 2017-01-02    2.0   16.0   4.75         PR14
#
#    promo_type_2 cluster_id hierarchy1_id storetype_id  store_size season week  \
# 0          PR03  cluster_1           H00         ST03          13      1    1
# 1          PR03  cluster_4           H00         ST03          13      1    1
# 2          PR03  cluster_7           H00         ST03          13      1    1
# 3          PR03  cluster_7           H00         ST03          13      1    1
# 4          PR03  cluster_0           H00         ST03          13      1    1
# 5          PR03  cluster_0           H01         ST03          13      1    1
# 6          PR03  cluster_0           H03         ST03          13      1    1
# 8          PR03  cluster_0           H00         ST03          13      1    1
# 9          PR03  cluster_0           H00         ST03          13      1    1
# 10         PR03  cluster_3           H00         ST03          13      1    1
# 11         PR03  cluster_5           H00         ST03          13      1    1
# 12         PR03  cluster_6           H00         ST03          13      1    1
# 13         PR03  cluster_0           H01         ST03          13      1    1
# 14         PR03  cluster_0           H03         ST03          13      1    1
# 15         PR03  cluster_0           H03         ST03          13      1    1
# 16         PR03  cluster_0           H00         ST03          13      1    1
# 17         PR03  cluster_8           H01         ST03          13      1    1
# 18         PR03  cluster_8           H03         ST03          13      1    1
# 19         PR03  cluster_0           H00         ST03          13      1    1
# 20         PR03  cluster_0           H00         ST03          13      1    1
#
#    holiday month_name
# 0        N        Jan
# 1        N        Jan
# 2        N        Jan
# 3        N        Jan
# 4        N        Jan
# 5        N        Jan
# 6        N        Jan
# 8        N        Jan
# 9        N        Jan
# 10       N        Jan
# 11       N        Jan
# 12       N        Jan
# 13       N        Jan
# 14       N        Jan
# 15       N        Jan
# 16       N        Jan
# 17       N        Jan
# 18       N        Jan
# 19       N        Jan
# 20       N        Jan
# 480
# 429

# %%
# Get unique store_ids
unique_store_ids = df_filtered['store_id'].unique()

# Create a dictionary of DataFrames, each keyed by store_id
store_datasets = {}
for store_id in unique_store_ids:
    store_datasets[store_id] = df_filtered[df_filtered['store_id'] == store_id].copy()

# dataset for store_id 'S0142'
store_S0142	 = store_datasets['S0142']
print("Store S0142 dataset:")
print(store_S0142.head())

# dataset for store_id S0094
store_S0094	 = store_datasets['S0094']
print("Store S0094 dataset:")
print(store_S0094.head())

# dataset for store_id S0030
store_S0030	 = store_datasets['S0030']
print("Store S0030 dataset:")
print(store_S0030.head())
# Out:
# StatementMeta(, 4c1f17b5-11af-4e1a-abc2-3092afa477d4, 8, Finished, Available, Finished)
# Store S0142 dataset:
#        store_id product_id       date  sales  stock  price promo_type_1  \
# 329162    S0142      P0005 2017-01-02    0.0    2.0  33.90         PR14
# 329163    S0142      P0015 2017-01-02    0.0   12.0   2.60         PR14
# 329164    S0142      P0017 2017-01-02    0.0   17.0   1.49         PR14
# 329165    S0142      P0018 2017-01-02    0.0    2.0   1.95         PR14
# 329168    S0142      P0051 2017-01-02    0.0   15.0   0.70         PR14
#
#        promo_type_2 cluster_id hierarchy1_id storetype_id  store_size season  \
# 329162         PR03  cluster_9           H03         ST04          31      1
# 329163         PR03  cluster_1           H00         ST04          31      1
# 329164         PR03  cluster_6           H00         ST04          31      1
# 329165         PR03  cluster_4           H00         ST04          31      1
# 329168         PR03  cluster_7           H00         ST04          31      1
#
#        week holiday month_name
# 329162    1       N        Jan
# 329163    1       N        Jan
# 329164    1       N        Jan
# 329165    1       N        Jan
# 329168    1       N        Jan
# Store S0094 dataset:
#       store_id product_id       date  sales  stock  price promo_type_1  \
# 62048    S0094      P0015 2017-01-02    0.0    6.0   2.60         PR14
# 62049    S0094      P0017 2017-01-02    0.0   91.0   1.49         PR14
# 62050    S0094      P0018 2017-01-02    0.0   17.0   1.95         PR14
# 62053    S0094      P0050 2017-01-02    0.0   11.0   5.95         PR05
# 62054    S0094      P0051 2017-01-02    0.0  132.0   0.70         PR14
#
#       promo_type_2 cluster_id hierarchy1_id storetype_id  store_size season  \
# 62048         PR03  cluster_1           H00         ST04          45      1
# 62049         PR03  cluster_6           H00         ST04          45      1
# 62050         PR03  cluster_4           H00         ST04          45      1
# 62053         PR03  cluster_9           H01         ST04          45      1
# 62054         PR03  cluster_7           H00         ST04          45      1
#
#       week holiday month_name
# 62048    1       N        Jan
# 62049    1       N        Jan
# 62050    1       N        Jan
# 62053    1       N        Jan
# 62054    1       N        Jan
# Store S0030 dataset:
#   store_id product_id       date  sales  stock  price promo_type_1  \
# 0    S0030      P0015 2017-01-02    0.0    4.0   2.60         PR14
# 1    S0030      P0018 2017-01-02    1.0    5.0   1.95         PR14
# 2    S0030      P0035 2017-01-02    2.0    1.0   2.45         PR14
# 3    S0030      P0051 2017-01-02    0.0   27.0   0.70         PR14
# 4    S0030      P0055 2017-01-02    0.0   12.0   3.50         PR05
#
#   promo_type_2 cluster_id hierarchy1_id storetype_id  store_size season week  \
# 0         PR03  cluster_1           H00         ST03          13      1    1
# 1         PR03  cluster_4           H00         ST03          13      1    1
# 2         PR03  cluster_7           H00         ST03          13      1    1
# 3         PR03  cluster_7           H00         ST03          13      1    1
# 4         PR03  cluster_0           H00         ST03          13      1    1
#
#   holiday month_name
# 0       N        Jan
# 1       N        Jan
# 2       N        Jan
# 3       N        Jan
# 4       N        Jan

# %%
# select store as df
df = store_S0094.copy() # replace according to store
# Out:
# StatementMeta(, 4c1f17b5-11af-4e1a-abc2-3092afa477d4, 9, Finished, Available, Finished)

# %%
# Change the granularity of time series data from daily to weekly

# Set 'ds' column as the index
df.set_index('date', inplace=True)
# Sort the DataFrame by the index (dates)
df.sort_index(inplace=True)

# Group by 'product_id' and resample to weekly frequency
df_week = df.groupby(['product_id']).resample('W-MON').agg({
    'sales': 'sum',  # Aggregate sales data
    'stock': 'last',  # Take the last stock value of the week
    'price': 'last',  # Last price for the week
    'promo_type_1': lambda x: x.mode().iloc[0] if not x.mode().empty else None,  # Mode of categorical variable
    'promo_type_2': lambda x: x.mode().iloc[0] if not x.mode().empty else None,  # Mode of categorical variable
    'cluster_id': lambda x: x.mode().iloc[0] if not x.mode().empty else None,  # Mode of categorical variable
    'hierarchy1_id': lambda x: x.mode().iloc[0] if not x.mode().empty else None,  # Mode of categorical variable
    'storetype_id': lambda x: x.mode().iloc[0] if not x.mode().empty else None,  # Mode of categorical variable
    'store_size': lambda x: x.mode().iloc[0] if not x.mode().empty else None,  # Mode of categorical variable
    'season': lambda x: x.mode().iloc[0] if not x.mode().empty else None,  # Mode of categorical variable
    'holiday': lambda x: x.mode().iloc[0] if not x.mode().empty else None, 
    'week': lambda x: x.mode().iloc[0] if not x.mode().empty else None,  # Mode of categorical variable
    'month_name': lambda x: x.mode().iloc[0] if not x.mode().empty else None,  # Mode of categorical variable
}).reset_index()

# Display the weekly aggregated DataFrame
print(df_week.head())
print(df_week.tail())


df_week.info()
# Out:
# StatementMeta(, 4c1f17b5-11af-4e1a-abc2-3092afa477d4, 10, Finished, Available, Finished)
#   product_id       date  sales  stock  price promo_type_1 promo_type_2  \
# 0      P0005 2018-01-15    0.0    6.0   39.9         PR14         PR03
# 1      P0005 2018-01-22    0.0    6.0   39.9         PR14         PR03
# 2      P0005 2018-01-29    0.0    6.0   39.9         PR14         PR03
# 3      P0005 2018-02-05    0.0    6.0   39.9         PR14         PR03
# 4      P0005 2018-02-12    0.0    6.0   39.9         PR14         PR03
#
#   cluster_id hierarchy1_id storetype_id  store_size  season holiday  week  \
# 0  cluster_9           H03         ST04        45.0     1.0       N   2.0
# 1  cluster_9           H03         ST04        45.0     1.0       N   3.0
# 2  cluster_9           H03         ST04        45.0     1.0       N   4.0
# 3  cluster_9           H03         ST04        45.0     1.0       N   5.0
# 4  cluster_9           H03         ST04        45.0     1.0       N   6.0
#
#   month_name
# 0        Jan
# 1        Jan
# 2        Jan
# 3        Feb
# 4        Feb
#       product_id       date  sales  stock  price promo_type_1 promo_type_2  \
# 39548      P0748 2019-09-02    0.0    4.0   18.9         PR05         PR03
# 39549      P0748 2019-09-09    0.0    4.0   18.9         PR14         PR03
# 39550      P0748 2019-09-16    0.0    4.0   18.9         PR14         PR03
# 39551      P0748 2019-09-23    0.0   16.0   18.9         PR14         PR03
# 39552      P0748 2019-09-30    0.0   16.0   18.9         PR14         PR03
#
#       cluster_id hierarchy1_id storetype_id  store_size  season holiday  week  \
# 39548  cluster_0           H01         ST04        45.0     3.0       N  35.0
# 39549  cluster_0           H01         ST04        45.0     3.0       N  36.0
# 39550  cluster_0           H01         ST04        45.0     3.0       N  37.0
# 39551  cluster_0           H01         ST04        45.0     3.0       N  38.0
# 39552  cluster_0           H01         ST04        45.0     3.0       N  39.0
#
#       month_name
# 39548        Aug
# 39549        Sep
# 39550        Sep
# 39551        Sep
# 39552        Sep
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39553 entries, 0 to 39552
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product_id     39553 non-null  category
#  1   date           39553 non-null  datetime64[ns]
#  2   sales          39553 non-null  float64
#  3   stock          36676 non-null  float64
#  4   price          36593 non-null  float64
#  5   promo_type_1   36676 non-null  object
#  6   promo_type_2   36676 non-null  object
#  7   cluster_id     36676 non-null  object
#  8   hierarchy1_id  36676 non-null  object
#  9   storetype_id   36676 non-null  object
#  10  store_size     36676 non-null  float64
#  11  season         36676 non-null  float64
#  12  holiday        36676 non-null  object
#  13  week           36676 non-null  float64
#  14  month_name     36676 non-null  object
# dtypes: category(1), datetime64[ns](1), float64(6), object(7)
# memory usage: 4.3+ MB

# %% [markdown]
# # **ARIMA**

# %% [markdown]
# # **TENTATIVA com exogenas**

# %%
# filter one product (top 3 sold)
# top 3 : P0453, P0125, P0536

# select 1 product (P0453) fom df
#df= df_week[df_week['product_id'] == 'P0453'].copy()
# select 1 product (P0125) fom df
#df= df_week[df_week['product_id'] == 'P0125'].copy()
# select 1 product (P0536) fom df
#df= df_week[df_week['product_id'] == 'P0536'].copy()

#select top 3
unique_ids = ['P0103', 'P0364', 'P0131']

# Filter the DataFrame based on the list of unique IDs
df_select = df_week[df_week['product_id'].isin(unique_ids)].copy()
# Out:
# StatementMeta(, 4c1f17b5-11af-4e1a-abc2-3092afa477d4, 11, Finished, Available, Finished)

# %%
df_select.info()
# Out:
# StatementMeta(, 4c1f17b5-11af-4e1a-abc2-3092afa477d4, 12, Finished, Available, Finished)
# <class 'pandas.core.frame.DataFrame'>
# Index: 432 entries, 4592 to 19311
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product_id     432 non-null    category
#  1   date           432 non-null    datetime64[ns]
#  2   sales          432 non-null    float64
#  3   stock          432 non-null    float64
#  4   price          432 non-null    float64
#  5   promo_type_1   432 non-null    object
#  6   promo_type_2   432 non-null    object
#  7   cluster_id     432 non-null    object
#  8   hierarchy1_id  432 non-null    object
#  9   storetype_id   432 non-null    object
#  10  store_size     432 non-null    float64
#  11  season         432 non-null    float64
#  12  holiday        432 non-null    object
#  13  week           432 non-null    float64
#  14  month_name     432 non-null    object
# dtypes: category(1), datetime64[ns](1), float64(6), object(7)
# memory usage: 71.4+ KB

# %%
# check missing values
missing_values_count = df_select.isna().sum()
missing_values_count
# Out:
# StatementMeta(, 4c1f17b5-11af-4e1a-abc2-3092afa477d4, 13, Finished, Available, Finished)
# product_id       0
# date             0
# sales            0
# stock            0
# price            0
# promo_type_1     0
# promo_type_2     0
# cluster_id       0
# hierarchy1_id    0
# storetype_id     0
# store_size       0
# season           0
# holiday          0
# week             0
# month_name       0
# dtype: int64

# %%
#df_weekly = df
# select drop columns accordingly
drop_columns = ['stock','hierarchy1_id', 'storetype_id',  'store_size', 'promo_type_1', 'promo_type_2', 'week', 'month_name', 'holiday', 'season', 'cluster_id']
#drop_columns = ['hierarchy1_id', 'storetype_id',  'store_size', 'promo_type_2', 'week', 'month_name']
#df_weekly = df_week.drop(columns = drop_columns) #for all products
df_weekly = df_select.drop(columns = drop_columns) # for selected products
# Out:
# StatementMeta(, 4c1f17b5-11af-4e1a-abc2-3092afa477d4, 14, Finished, Available, Finished)

# %% [markdown]
# **Arima without encoder (for non categorical variables only, (price))**

# %%
# Adjust column names 
df_weekly = df_weekly.rename(columns={
    'product_id': 'unique_id',
    'date': 'ds',
    'sales': 'y'
})


def perform_forecasting(df_weekly, unique_id):


    filter_df = df_weekly[df_weekly['unique_id'] == unique_id].copy()

    # Extract the last date in the dataset
    last_date = filter_df['ds'].max()


    # Separate sales and date from exogeneous variables

    # Selecting and renaming the columns for the first DataFrame
    Y_ts = filter_df[['unique_id', 'ds', 'y']]

    # Selecting and renaming the columns for the second DataFrame
    X_ts = filter_df.drop(columns=['y'])
    X_ts['unique_id'] = X_ts.unique_id.astype(str)

    # Extract dates for train and test set 
    dates = Y_ts['ds'].unique()
    dtrain = dates[:-2] #2 weeks
    dtest = dates[-2:]

    Y_train = Y_ts.query('ds in @dtrain')
    Y_test = Y_ts.query('ds in @dtest') 

    X_train = X_ts.query('ds in @dtrain') 
    X_test = X_ts.query('ds in @dtest')


    #insert encode

    # Calculate median prices for each unique_id in X_train
    median_prices_1 = X_train.groupby('unique_id')['price'].transform('median')
    median_prices_2 = X_test.groupby('unique_id')['price'].transform('median')
    median_prices_3 = X_ts.groupby('unique_id')['price'].transform('median')


    # Find unique_ids with NaN median prices
    ids_with_nan_median_1 = X_train['unique_id'][median_prices_1.isnull()].unique()
    ids_with_nan_median_2 = X_test['unique_id'][median_prices_2.isnull()].unique()
    ids_with_nan_median_3 = X_ts['unique_id'][median_prices_3.isnull()].unique()


    # Fill NaN values in 'price' column with median prices (except for those with NaN median)
    X_train['price'].fillna(median_prices_1, inplace=True)
    X_test['price'].fillna(median_prices_2, inplace=True)
    X_ts['price'].fillna(median_prices_3, inplace=True)


    '''X_train['stock'] = X_train['stock'].fillna(method='ffill')
    X_test['stock'] = X_test['stock'].fillna(method='ffill')
    X_ts['stock'] = X_ts['stock'].fillna(method='ffill')'''


    # Fill NaN values for specific unique_ids with a default value (e.g., 0 or another appropriate value)
    default_price = 0  # Change this to your desired default value
    X_train.loc[X_train['unique_id'].isin(ids_with_nan_median_1) & X_train['price'].isnull(), 'price'] = default_price
    X_test.loc[X_test['unique_id'].isin(ids_with_nan_median_2) & X_test['price'].isnull(), 'price'] = default_price
    X_ts.loc[X_test['unique_id'].isin(ids_with_nan_median_3) & X_ts['price'].isnull(), 'price'] = default_price



    # Merge Y_train with X_ts to create the training dataset
    train = pd.merge(Y_train, X_ts, on=['unique_id', 'ds'], how='left')


    # Define models to use
    models = [AutoARIMA(season_length=52)] # represents weekly data

    # Define statsforecast object
    sf = StatsForecast(
        models=models, 
        freq='W-MON', # weekly frequency
        n_jobs=-1,
    )

    # Define horizon and level for AutoARIMA
    horizon = 2
    level = [95]

    # Forecast
    fcst = sf.forecast(df=train, h=horizon, X_df=X_test, level=level)
    fcst.head()

    # Extract predictions
    autoarima_predictions = fcst['AutoARIMA'].values

    # Evaluate the accuracy
    res = pd.merge(Y_test, fcst, on=['unique_id', 'ds'], how='left')

    # Calculate metrics
    mae = abs(res['y'] - res['AutoARIMA']).mean()
    mse = mean_squared_error(res['y'], res['AutoARIMA'])  # Using sklearn.metrics for MSE
    rmse = mse ** 0.5
    epsilon = 1e-10  # Small constant to avoid division by zero
    mape = (abs(res['y'] - res['AutoARIMA']) / (res['y'] + epsilon)).mean() * 100

    absolute_errors = abs(res['y'] - res['AutoARIMA'])
    wmape = (absolute_errors.sum() / abs(res['y']).sum()) * 100
            

    # Prepare future X_df
    future_dates = pd.date_range(start=last_date + pd.DateOffset(weeks=1), periods=horizon, freq='W-MON')

        # Find the last valid price for the specific unique_id in X_ts
    last_valid_price = X_ts['price'][(X_ts['unique_id'] == unique_id) & X_ts['price'].notna() & 
                                     (X_ts['price'] != float('inf')) & (X_ts['price'] != float('-inf'))].iloc[-1]

    future_X_df = pd.DataFrame({
        'unique_id': unique_id,
        'ds': future_dates,
        'price': last_valid_price
    })

    # Merge Y_ts with X_ts to create the training dataset
    predict_df = pd.merge(Y_ts, X_ts, on=['unique_id', 'ds'], how='left')

    # Train on entire dataset including the last 2 weeks
    fcst_final = sf.forecast(df=predict_df, h=horizon, X_df = future_X_df, level = level)



    # Return results 
    return {
        'unique_id': unique_id,
        'MAE': mae,
        'MSE': mse,
        'RMSE': rmse,
        'MAPE': mape,
        'WMAPE':wmape,
        'AutoARIMA_Predictions': autoarima_predictions,
        'Final_Predictions': fcst_final['AutoARIMA'].values

    }


# Loop through each product and perform forecasting
unique_ids = df_weekly['unique_id'].unique()  # Get all unique_ids
results_list = []


for unique_id in unique_ids:
    results = perform_forecasting(df_weekly, unique_id)
    results_list.append(results)
    
    
    
# Convert results to a DataFrame
results_df = pd.DataFrame(results_list)
print(results_df)
# Out:
# StatementMeta(, 4c1f17b5-11af-4e1a-abc2-3092afa477d4, 15, Finished, Available, Finished)
#   unique_id        MAE         MSE       RMSE        MAPE      WMAPE  \
# 0     P0103  23.596813  717.549922  26.787122  165.512886  94.387253
# 1     P0131  14.876328  240.544339  15.509492   26.770668  26.098820
# 2     P0364  13.817267  198.282125  14.081269   38.740841  36.846046
#
#     AutoARIMA_Predictions       Final_Predictions
# 0  [48.275154, 48.918472]  [41.744858, 43.458923]
# 1   [71.490074, 72.26258]    [58.94537, 61.15419]
# 2  [31.896631, 48.531166]   [40.910347, 48.38183]

# %%
results = pd.DataFrame(results_df)
results
# Out:
# StatementMeta(, 4c1f17b5-11af-4e1a-abc2-3092afa477d4, 16, Finished, Available, Finished)
#   unique_id        MAE         MSE       RMSE        MAPE      WMAPE  \
# 0     P0103  23.596813  717.549922  26.787122  165.512886  94.387253
# 1     P0131  14.876328  240.544339  15.509492   26.770668  26.098820
# 2     P0364  13.817267  198.282125  14.081269   38.740841  36.846046
#
#     AutoARIMA_Predictions       Final_Predictions
# 0  [48.275154, 48.918472]  [41.744858, 43.458923]
# 1   [71.490074, 72.26258]    [58.94537, 61.15419]
# 2  [31.896631, 48.531166]   [40.910347, 48.38183]

# %%
#Saving csv
metrics_path = 'abfss://Projeto_ii_ML_models@onelake.dfs.fabric.microsoft.com/Konya_sales.Lakehouse/Files/W_exog vs Wout_exog/Exog_S0094_metrics_valid_forecast_price.csv'
results.to_csv(metrics_path, index=False)
# Out:
# StatementMeta(, 4c1f17b5-11af-4e1a-abc2-3092afa477d4, 17, Finished, Available, Finished)

# %% [markdown]
# **Arima with encoder (for categorical variables)**
#
# testado para: top 3 products of store S0094, with price, stock and categorical variable: 'holiday', 'season', 'cluster_id', 'promo_type_1  -- OK

# %%
#df_weekly = df
# select drop columns accordingly
#drop_columns = ['hierarchy1_id', 'storetype_id',  'store_size', 'promo_type_1', 'promo_type_2', 'week', 'month_name', 'holiday', 'season', 'cluster_id']
drop_columns = ['stock','hierarchy1_id', 'storetype_id',  'store_size', 'promo_type_2', 'week', 'month_name']
#df_weekly = df_week.drop(columns = drop_columns) #for all products
df_weekly = df_select.drop(columns = drop_columns) # for selected products
# Out:
# StatementMeta(, 4c1f17b5-11af-4e1a-abc2-3092afa477d4, 18, Finished, Available, Finished)

# %%
# Adjust column names 
df_weekly = df_weekly.rename(columns={
    'product_id': 'unique_id',
    'date': 'ds',
    'sales': 'y'
})



def perform_forecasting(df_weekly, unique_id, deficiency_threshold=0.1):

    # Filter DataFrame for the specified unique_id
    filter_df = df_weekly[df_weekly['unique_id'] == unique_id].copy()

    # Extract the last date in the dataset
    last_date = filter_df['ds'].max()

    # Selecting and renaming the columns for the first DataFrame
    Y_ts = filter_df[['unique_id', 'ds', 'y']]

    # Selecting and renaming the columns for the second DataFrame
    X_ts = filter_df.drop(columns=['y'])
    X_ts['unique_id'] = X_ts['unique_id'].astype(str)

    # Extract dates for train and test set 
    dates = Y_ts['ds'].unique()
    dtrain = dates[:-2] # 2 weeks
    dtest = dates[-2:]

    Y_train = Y_ts.query('ds in @dtrain')
    Y_test = Y_ts.query('ds in @dtest') 

    X_train = X_ts.query('ds in @dtrain') 
    X_test = X_ts.query('ds in @dtest')

    # Merge Y_train with X_ts to create the training dataset
    train1 = pd.merge(Y_train, X_ts, on=['unique_id', 'ds'], how='left')

    # Define categorical columns list
    categorical_cols = ['holiday', 'season', 'cluster_id', 'promo_type_1']
    # Initialize OneHotEncoder
    encoder = OneHotEncoder(sparse=False, drop='first', handle_unknown='ignore')

    # Fit and transform X_train
    X_train_encoded = pd.DataFrame(encoder.fit_transform(X_train[categorical_cols]), columns=encoder.get_feature_names_out(categorical_cols))
    # Reset index of X_train_encoded to match X_train
    X_train_encoded.index = X_train.index
    # Drop original categorical columns from X_train
    X_train = X_train.drop(columns=categorical_cols)
    # Concatenate X_train with X_train_encoded
    X_train = pd.concat([X_train, X_train_encoded], axis=1)

    # Transform X_test
    X_encoded_test = pd.DataFrame(encoder.transform(X_test[categorical_cols]), columns=encoder.get_feature_names_out(categorical_cols))
    # Reset index of X_encoded_test to match X_test
    X_encoded_test.index = X_test.index
    # Drop original categorical columns from X_test
    X_test = X_test.drop(columns=categorical_cols)
    # Concatenate X_test with X_encoded_test
    X_test = pd.concat([X_test, X_encoded_test], axis=1)

    # Transform X_ts
    X_ts_encoded = pd.DataFrame(encoder.transform(X_ts[categorical_cols]), columns=encoder.get_feature_names_out(categorical_cols))
    # Reset index of X_encoded_ts to match X_ts
    X_ts_encoded.index = X_ts.index
    # Drop original categorical columns from X_ts
    X_ts = X_ts.drop(columns=categorical_cols)
    # Concatenate X_test with X_encoded_test
    X_ts = pd.concat([X_ts, X_ts_encoded], axis=1)


    # Transform train1
    train1_encoded = pd.DataFrame(encoder.transform(train1[categorical_cols]), columns=encoder.get_feature_names_out(categorical_cols))
    # Reset index of train1_encoded to match train1
    train1_encoded.index = train1.index
    # Drop original categorical columns from train1
    train1 = train1.drop(columns=categorical_cols)
    # Concatenate train1 with train1_encoded
    train1 = pd.concat([train1, train1_encoded], axis=1)

    # Calculate median prices for each unique_id in X_train
    median_prices_1 = X_train.groupby('unique_id')['price'].transform('median')
    median_prices_2 = X_test.groupby('unique_id')['price'].transform('median')
    median_prices_3 = X_ts.groupby('unique_id')['price'].transform('median')

    # Find unique_ids with NaN median prices
    ids_with_nan_median_1 = X_train['unique_id'][median_prices_1.isnull()].unique()
    ids_with_nan_median_2 = X_test['unique_id'][median_prices_2.isnull()].unique()
    ids_with_nan_median_3 = X_ts['unique_id'][median_prices_3.isnull()].unique()

    # Fill NaN values in 'price' column with median prices (except for those with NaN median)
    X_train['price'].fillna(median_prices_1, inplace=True)
    X_test['price'].fillna(median_prices_2, inplace=True)
    X_ts['price'].fillna(median_prices_3, inplace=True)

    # Fill NaN values for specific unique_ids with a default value (e.g., 0 or another appropriate value)
    default_price = 0  # Change this to your desired default value
    X_train.loc[X_train['unique_id'].isin(ids_with_nan_median_1) & X_train['price'].isnull(), 'price'] = default_price
    X_test.loc[X_test['unique_id'].isin(ids_with_nan_median_2) & X_test['price'].isnull(), 'price'] = default_price
    X_ts.loc[X_ts['unique_id'].isin(ids_with_nan_median_3) & X_ts['price'].isnull(), 'price'] = default_price

    # Check if xregs are deficient
    is_deficient = X_train.isnull().mean().mean() > deficiency_threshold

    if is_deficient:
        # Define models to use without xregs
        models = [AutoARIMA(season_length=52)] # represents weekly data
        X_train = None
        X_test = None
    else:
        # Define models to use with xregs
        models = [AutoARIMA(season_length=52)] # represents weekly data

    # Define statsforecast object
    sf = StatsForecast(
        models=models, 
        freq='W-MON', # weekly frequency
        n_jobs=-1,
    )

    # Define horizon and level for AutoARIMA
    horizon = 2
    level = [95]

    # Forecast
    fcst = sf.forecast(df=train1, h=horizon, X_df=X_test, level=level)

    # Extract predictions
    autoarima_predictions = fcst['AutoARIMA'].values

    # Evaluate the accuracy
    res = pd.merge(Y_test, fcst, on=['unique_id', 'ds'], how='left')

    # Calculate metrics
    mae = abs(res['y'] - res['AutoARIMA']).mean()
    mse = mean_squared_error(res['y'], res['AutoARIMA'])  # Using sklearn.metrics for MSE
    rmse = mse ** 0.5
    epsilon = 1e-10  # Small constant to avoid division by zero
    mape = (abs(res['y'] - res['AutoARIMA']) / (res['y'] + epsilon)).mean() * 100

    absolute_errors = abs(res['y'] - res['AutoARIMA'])
    wmape = (absolute_errors.sum() / abs(res['y']).sum()) * 100

    # Prepare future X_df
    future_dates = pd.date_range(start=last_date + pd.DateOffset(weeks=1), periods=horizon, freq='W-MON')

        # Find the last valid price for the specific unique_id in X_ts
    last_valid_price = X_ts['price'][(X_ts['unique_id'] == unique_id) & X_ts['price'].notna() & 
                                     (X_ts['price'] != float('inf')) & (X_ts['price'] != float('-inf'))].iloc[-1]

    # Extract the last available row from X_ts
    last_row = X_ts.iloc[-1]

    # Get the unique_id and encoded variables (excluding 'ds' and 'price')
    unique_id = last_row['unique_id']
    encoded_vars = last_row.drop(['unique_id', 'ds', 'price'])

    future_X_df = pd.DataFrame({
        'unique_id': unique_id,
        'ds': future_dates,
        'price': last_valid_price,

    })

    # Add the encoded variables
    for col in encoded_vars.index:
        future_X_df[col] = encoded_vars[col]

    # Merge Y_ts with X_ts to create the training dataset
    predict_df = pd.merge(Y_ts, X_ts, on=['unique_id', 'ds'], how='left')

    # Train on entire dataset including the last 2 weeks
    fcst_final = sf.forecast(df=predict_df, h=horizon, X_df = future_X_df, level = level)



    # Return results 
    return {
        'unique_id': unique_id,
        'MAE': mae,
        'MSE': mse,
        'RMSE': rmse,
        'MAPE': mape,
        'WMAPE':wmape,
        'AutoARIMA_Predictions': autoarima_predictions,
        'Final_Predictions': fcst_final['AutoARIMA'].values

    }

# Create loop for all products:
unique_ids = df_weekly['unique_id'].unique()  # Get all unique_ids
results_list = []

for unique_id in unique_ids:
    results = perform_forecasting(df_weekly, unique_id)
    results_list.append(results)

# Convert results to a DataFrame
results_df1 = pd.DataFrame(results_list)
print(results_df1)
# Out:
# StatementMeta(, 4c1f17b5-11af-4e1a-abc2-3092afa477d4, 21, Finished, Available, Finished)
#   unique_id        MAE         MSE       RMSE        MAPE      WMAPE  \
# 0     P0103  22.284176  614.671553  24.792571  153.151892  89.136703
# 1     P0131  16.331470  297.544831  17.249488   29.480451  28.651703
# 2     P0364   7.448271   85.441132   9.243437   22.486702  19.862055
#
#     AutoARIMA_Predictions       Final_Predictions
# 0   [45.150963, 49.41739]   [40.563553, 42.76664]
# 1    [71.77918, 74.88376]   [63.857674, 68.03681]
# 2  [44.974297, 44.922245]  [34.995148, 35.565525]

# %%
results1 = pd.DataFrame(results_df1)
results1
# Out:
# StatementMeta(, 4c1f17b5-11af-4e1a-abc2-3092afa477d4, 22, Finished, Available, Finished)
#   unique_id        MAE         MSE       RMSE        MAPE      WMAPE  \
# 0     P0103  22.284176  614.671553  24.792571  153.151892  89.136703
# 1     P0131  16.331470  297.544831  17.249488   29.480451  28.651703
# 2     P0364   7.448271   85.441132   9.243437   22.486702  19.862055
#
#     AutoARIMA_Predictions       Final_Predictions
# 0   [45.150963, 49.41739]   [40.563553, 42.76664]
# 1    [71.77918, 74.88376]   [63.857674, 68.03681]
# 2  [44.974297, 44.922245]  [34.995148, 35.565525]

# %% [markdown]
# **Save model**

# %%
#Saving csv
metrics_path = 'abfss://Projeto_ii_ML_models@onelake.dfs.fabric.microsoft.com/Konya_sales.Lakehouse/Files/W_exog vs Wout_exog/Exog_S0094_metrics_valid_forecast_exog_price_holiday_promo_type_1_season_cluster_id.csv'
results1.to_csv(metrics_path, index=False)
# Out:
# StatementMeta(, 4c1f17b5-11af-4e1a-abc2-3092afa477d4, 23, Finished, Available, Finished)
